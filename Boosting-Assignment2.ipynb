# %%
Q1. What is Gradient Boosting Regression?

# %% [markdown]
# #### Gradient boosting Regression calculates the difference between the current prediction and the known correct target value. This difference is called residual. After that Gradient boosting Regression trains a weak model that maps features to that residual.

# %%
Q2. Implement a simple gradient boosting algorithm from scratch using Python and NumPy. Use a 
simple regression problem as an example and train the model on a small dataset. Evaluate the model's 
performance using metrics such as mean squared error and R-squared.

# %%
from sklearn.datasets import make_regression
X, y = make_regression(n_features=4, n_informative=2,
                       random_state=0, shuffle=False)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
Reg3=GradientBoostingRegressor()
Reg3.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred3=Reg3.predict(X_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
score=r2_score(y_test,y_pred3)
mae=mean_absolute_error(y_test,y_pred3)
print("r2 score of XgBoostRegressor is ", score)
print("mae is of XgBoostRegressor is", mae)
# Out:
# r2 score of XgBoostRegressor is  0.9381377313678131
# mae is of XgBoostRegressor is 6.637529714250673

# %%
Q3. Experiment with different hyperparameters such as learning rate, number of trees, and tree depth to 
optimise the performance of the model. Use grid search or random search to find the best 
hyperparameters

# %%
## Hypeparameter Tuning
params={'learning_rate':[0.1,0.2,0.3],
               'max_depth':[2,3,4]
              }

# %%
from sklearn.model_selection import RandomizedSearchCV
cv=RandomizedSearchCV(Reg3,param_distributions=params,scoring='accuracy',cv=5,verbose=3)
cv.fit(X_train,y_train)
# Out:
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END ......learning_rate=0.1, max_depth=2;, score=nan total time=   0.0s
# [CV 2/5] END ......learning_rate=0.1, max_depth=2;, score=nan total time=   0.0s
# [CV 3/5] END ......learning_rate=0.1, max_depth=2;, score=nan total time=   0.0s
# [CV 4/5] END ......learning_rate=0.1, max_depth=2;, score=nan total time=   0.0s
# [CV 5/5] END ......learning_rate=0.1, max_depth=2;, score=nan total time=   0.0s
# [CV 1/5] END ......learning_rate=0.1, max_depth=3;, score=nan total time=   0.0s
# [CV 2/5] END ......learning_rate=0.1, max_depth=3;, score=nan total time=   0.0s
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# [CV 3/5] END ......learning_rate=0.1, max_depth=3;, score=nan total time=   0.0s
# [CV 4/5] END ......learning_rate=0.1, max_depth=3;, score=nan total time=   0.0s
# [CV 5/5] END ......learning_rate=0.1, max_depth=3;, score=nan total time=   0.0s
# [CV 1/5] END ......learning_rate=0.1, max_depth=4;, score=nan total time=   0.0s
# [CV 2/5] END ......learning_rate=0.1, max_depth=4;, score=nan total time=   0.0s
# [CV 3/5] END ......learning_rate=0.1, max_depth=4;, score=nan total time=   0.0s
# [CV 4/5] END ......learning_rate=0.1, max_depth=4;, score=nan total time=   0.0s
# [CV 5/5] END ......learning_rate=0.1, max_depth=4;, score=nan total time=   0.0s
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# [CV 1/5] END ......learning_rate=0.2, max_depth=2;, score=nan total time=   0.0s
# [CV 2/5] END ......learning_rate=0.2, max_depth=2;, score=nan total time=   0.0s
# [CV 3/5] END ......learning_rate=0.2, max_depth=2;, score=nan total time=   0.0s
# [CV 4/5] END ......learning_rate=0.2, max_depth=2;, score=nan total time=   0.0s
# [CV 5/5] END ......learning_rate=0.2, max_depth=2;, score=nan total time=   0.0s
# [CV 1/5] END ......learning_rate=0.2, max_depth=3;, score=nan total time=   0.0s
# [CV 2/5] END ......learning_rate=0.2, max_depth=3;, score=nan total time=   0.0s
# [CV 3/5] END ......learning_rate=0.2, max_depth=3;, score=nan total time=   0.0s
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# [CV 4/5] END ......learning_rate=0.2, max_depth=3;, score=nan total time=   0.0s
# [CV 5/5] END ......learning_rate=0.2, max_depth=3;, score=nan total time=   0.0s
# [CV 1/5] END ......learning_rate=0.2, max_depth=4;, score=nan total time=   0.0s
# [CV 2/5] END ......learning_rate=0.2, max_depth=4;, score=nan total time=   0.0s
# [CV 3/5] END ......learning_rate=0.2, max_depth=4;, score=nan total time=   0.0s
# [CV 4/5] END ......learning_rate=0.2, max_depth=4;, score=nan total time=   0.0s
# [CV 5/5] END ......learning_rate=0.2, max_depth=4;, score=nan total time=   0.0s
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# [CV 1/5] END ......learning_rate=0.3, max_depth=2;, score=nan total time=   0.0s
# [CV 2/5] END ......learning_rate=0.3, max_depth=2;, score=nan total time=   0.0s
# [CV 3/5] END ......learning_rate=0.3, max_depth=2;, score=nan total time=   0.0s
# [CV 4/5] END ......learning_rate=0.3, max_depth=2;, score=nan total time=   0.0s
# [CV 5/5] END ......learning_rate=0.3, max_depth=2;, score=nan total time=   0.0s
# [CV 1/5] END ......learning_rate=0.3, max_depth=3;, score=nan total time=   0.0s
# [CV 2/5] END ......learning_rate=0.3, max_depth=3;, score=nan total time=   0.0s
# [CV 3/5] END ......learning_rate=0.3, max_depth=3;, score=nan total time=   0.0s
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\mallu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\mallu\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# [CV 4/5] END ......learning_rate=0.3, max_depth=3;, score=nan total time=   0.0s
# [CV 5/5] END ......learning_rate=0.3, max_depth=3;, score=nan total time=   0.0s
# [CV 1/5] END ......learning_rate=0.3, max_depth=4;, score=nan total time=   0.0s
# [CV 2/5] END ......learning_rate=0.3, max_depth=4;, score=nan total time=   0.0s
# [CV 3/5] END ......learning_rate=0.3, max_depth=4;, score=nan total time=   0.0s
# [CV 4/5] END ......learning_rate=0.3, max_depth=4;, score=nan total time=   0.0s
# [CV 5/5] END ......learning_rate=0.3, max_depth=4;, score=nan total time=   0.0s
# RandomizedSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#                    param_distributions={'learning_rate': [0.1, 0.2, 0.3],
#                                         'max_depth': [2, 3, 4]},
#                    scoring='accuracy', verbose=3)

# %%
cv.best_params_
# Out:
# {'max_depth': 2, 'learning_rate': 0.1}

# %%
y_pred3=cv.predict(X_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
score=r2_score(y_test,y_pred3)
mae=mean_absolute_error(y_test,y_pred3)
print("r2 score of GradientBoostRegressor is ", score)
print("mae is of GradientBoostRegressor is", mae)
# Out:
# r2 score of GradientBoostRegressor is  0.9538591218941925
# mae is of GradientBoostRegressor is 6.0010091422351515

# %%
Q4. What is a weak learner in Gradient Boosting?

# %% [markdown]
# #### Decision trees are used as the weak learner in gradient boosting.

# %%
Q5. What is the intuition behind the Gradient Boosting algorithm?

# %% [markdown]
# #### In gradient boosting, we predict and adjust our predictions in the opposite (negative gradient) direction. This achieves the opposite (minimize the loss). Since, the loss of a model inversely relates to its performance and accuracy, doing so improves its performance

# %%
Q6. How does Gradient Boosting algorithm build an ensemble of weak learners?

# %% [markdown]
# #### Decision trees are used as the weak learner in gradient boosting. Specifically regression trees are used that output real values for splits and whose output can be added together, allowing subsequent models outputs to be added and “correct” the residuals in the predictions.

# %%
Q7. What are the steps involved in constructing the mathematical intuition of Gradient Boosting 
algorithm?

# %% [markdown]
# #### Each gradient boosting algorithm iteration consists of two steps: the first step assesses the current residuals or discrepancies between actual and predicted values, while the second applies gradient descent to optimize parameters of individual base learners.

# %% [markdown]
# #### steps involved in constructing the mathematical intuition of Gradient Boosting
# algorithm
#
# Step 1 : Make the first guess
#
# Step 2 : Compute the pseudo-residuals
#
# Step 3 : Predict the pseudo-residuals
#
# Step 4 : Make a prediction and compute the residual
#
# Step 5 : Make a second prediction
